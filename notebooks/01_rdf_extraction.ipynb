# %%
import pandas as pd
import sklearn
import rdflib
print("Test ok")
# Out:
# Test ok

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Leandro\Documents\NCI\Year 3\Artificial Intelligence\AI_CA_2025_CityPulse\.venv\Scripts\python.exe
